# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
import numpy as np
from sklearn.pipeline import Pipeline

# %%
# 导入数据
source = pd.read_csv(r"D:\raicom\2024-big-data-raicom\practicesklearn\data\winequality-red.csv")
source.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# 空值检测
source.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
source.iloc[:5]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
features = source.drop(columns=["quality"])
target = source["quality"]

# 数据集划分
xtrain,xtest,ytrain,ytest = train_test_split(features,target,train_size=0.8,test_size=0.2,random_state=42)

# %%
# 数据标准化
scaler = StandardScaler()

x_scaler = scaler.fit_transform(xtrain)
y_scaler = scaler.fit_transform(xtest)

# %%
# 构建模型，使用网格搜索寻找最优超参数
parameters = {"criterion": ["gini","entropy"]
              , "splitter": ["best","random"]
              , "max_depth": [1,2,4,8,10,15,20,None]
              , "min_samples_leaf": [2,3,4,5,8,10]
              , "min_samples_split": [2,3,4,5,8,10,13,]
             }
model = GridSearchCV(estimator=DecisionTreeClassifier(), param_grid=parameters, n_jobs=-1, cv=5, verbose=1)
model.fit(x_scaler,ytrain)
# Out:
# Fitting 5 folds for each of 1344 candidates, totalling 6720 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [1, 2, 4, 8, 10, 15, 20, None],
#                          'min_samples_leaf': [2, 3, 4, 5, 8, 10],
#                          'min_samples_split': [2, 3, 4, 5, 8, 10, 13],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
display(model.best_params_,model.best_score_)
# Out:
# {'criterion': 'gini',
#  'max_depth': 20,
#  'min_samples_leaf': 10,
#  'min_samples_split': 8,
#  'splitter': 'random'}
# np.float64(0.6036427696078431)

# %%
model.score(y_scaler,ytest.values)
# Out:
# 0.5
